# %% [markdown]
# # Calulator

# %% [markdown]
# # Hotel booking

# %%
print("Available Cities:")
print("1. Pune")
print("2. Mumbai")
print("3. Delhi")
print("4. Kolkata")
print("5. Hyderabad")
print("6. Chennai")
print("7. Shimla")
print("8. Kashmir")
print("9. Sri Lanka")
print("10. Singapore")
print("11. Kerala")
print("12. Bangalore")
print()

location = int(input("Enter your location: "))
print()

if location == 1:
    location_name = "Pune"
elif location == 2:
    location_name = "Mumbai"
elif location == 3:
    location_name = "Delhi"
elif location == 4:
    location_name = "Kolkata"
elif location == 5:
    location_name = "Hyderabad"
elif location == 6:
    location_name = "Chennai"
elif location == 7:
    location_name = "Shimla"
elif location == 8:
    location_name = "kashmir"
elif location == 9:
    location_name = "sri lanka"
elif location == 10:
    location_name = "singapoore"
elif location == 11:
    location_name = "kerala"
elif location == 12:
    location_name = "Bangloore"    
else:
    print("Invalid choice. Please select a city from 1 to 12.")
    exit()


check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y")
print()
check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "),"%d-%m-%Y")
print()
room = input("Enter requirements of the room: ")
print()
adults = int(input("Enter the number of adults: "))
print()
children = int(input("Enter the number of children (0-17 years): "))
print()


print("1. Normal Room")
print("2. Super Delux room")
print("3. Delux Room")

type_of_room=int(input("Enter type of room requirement?:"))
print()
if type_of_room== 1:
    Normal_room = 500
elif type_of_room == 2:
    Delux_room = 1000
elif type_of_room== 3:
    Super_Delux_room  = 2000
else:
    print("Invalid room choice. Please enter a number between 1 and 3.")
    
print("1. 1000")
print("2. 2000")
print("3. 5000")

hotel_price_per_day = int(input("Enter the hotel price per day: "))
print()

print("Location:", location_name)
print("Check-in Date:", check_in_date)
print("Check-out Date:", check_out_date)
print("Room Requirement:", room)
print("Number of Adults:", adults)
print("Number of Children:", children)
print("Type of room requirment:",type_of_room)
print("hotel price per day:",hotel_price_per_day)

num_days = (check_out_date - check_in_date).days
total_hotel_price = num_days * total_hotel_price_per_day

print("Total Price for hotel:", total_hotel_price)
print()
print("Total Number of Days:", num_days)
print()
print("Total Price:", total_hotel_price)
# Out:
# Available Cities:
# 1. Pune
# 2. Mumbai
# 3. Delhi
# 4. Kolkata
# 5. Hyderabad
# 6. Chennai
# 7. Shimla
# 8. Kashmir
# 9. Sri Lanka
# 10. Singapore
# 11. Kerala
# 12. Bangalore
#
# Enter your location: 1
#
# Enter the check-in date (DD-MM-YYYY): 15-5-2024
#
# Enter the check-out date (DD-MM-YYYY): 20-5-2024
#
# Enter requirements of the room: 2
#
# Enter the number of adults: 1
#
# Enter the number of children (0-17 years): 1
#
# 1. Normal Room
# 2. Super Delux room
# 3. Delux Room
# Enter type of room requirement?:2
#
# 1. 1000
# 2. 2000
# 3. 5000
# Enter the hotel price per day: 2
#
# Location: Pune
# Check-in Date: 2024-05-15 00:00:00
# Check-out Date: 2024-05-20 00:00:00
# Room Requirement: 2
# Number of Adults: 1
# Number of Children: 1
# Type of room requirment: 2
# hotel price per day: 2
# Total Price for hotel: 7500
#
# Total Number of Days: 5
#
# Total Price: 7500

# %%
from datetime import datetime
# print("Available Cities:")
print("1. Pune")
print("2. Mumbai")
print("3. Delhi")
print("4. Kolkata")
print("5. Hyderabad")
print("6. Chennai")
print("7. Shimla")
print("8. Kashmir")
print("9. Sri Lanka")
print("10. Singapore")
print("11. Kerala")
print("12. Bangalore")
print()

location = int(input("Enter your location: "))
print()

if location == 1:
    location_name = "Pune"

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  500")
    print("2. Super Deluxe room  1000")
    print("3. Deluxe Room  2000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 500
        hotel_name= "Procida Hostel by ZJ Viman Nagar Near Airport"
    elif type_of_room == 2:
        room_price_per_day = 1000
        hotel_name= "Hamlet Studio Apartments with Balcony"
    elif type_of_room == 3:
        room_price_per_day = 2000
        hotel_name= "Lemon Tree Hotel Hinjawadi"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
   
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
    
elif location == 2:
    location_name = "Mumbai"
   
    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  1000")
    print("2. Super Deluxe room  2000")
    print("3. Deluxe Room  5000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 1000
        hotel_name= "Empire Royale Hotel"
    elif type_of_room == 2:
        room_price_per_day = 2000
        hotel_name= "Hotel Cliffton"
    elif type_of_room == 3:
        room_price_per_day = 5000
        hotel_name= "Radisson Blu Mumbai International Airport"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 3:
    location_name = "Delhi"    

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  3000")
    print("2. Super Deluxe room  5000")
    print("3. Deluxe Room  10000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 3000
        hotel_name= "FabHotel Cabana"
    elif type_of_room == 2:
        room_price_per_day = 5000
        hotel_name= "The park"
    elif type_of_room == 3:
        room_price_per_day = 10000
        hotel_name= "Le Méridien New Delhi"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 4:
    location_name = "Kolkata"
  

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  1500")
    print("2. Super Deluxe room  4000")
    print("3. Deluxe Room  10000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 1500
        hotel_name= "Hotel Park Victoria"
    elif type_of_room == 2:
        room_price_per_day = 4000
        hotel_name= "Golden Orchid - Kolkata"
    elif type_of_room == 3:
        room_price_per_day = 10000
        hotel_name= "Itc Royal Bengal, A Luxury Collection Hotel, Kolkat" 
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
        
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 6:
    location_name = "Chennai"
  

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  2500")
    print("2. Super Deluxe room  4000")
    print("3. Deluxe Room  10000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 2500
        hotel_name= "Sheraton Grande Hotel Chennai"
    elif type_of_room == 2:
        room_price_per_day = 5000
        hotel_name= "The Pride Chennai Hotel"
    elif type_of_room == 3:
        room_price_per_day = 10000
        hotel_name= "Taj Club House"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 7:
    location_name = "Shimla"
    

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  3000")
    print("2. Super Deluxe room  5000")
    print("3. Deluxe Room  15000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 3000
        hotel_name= "Snow Valley Resorts Shimla"
    elif type_of_room == 2:
        room_price_per_day = 5000
        hotel_name= "Snow Valley Heights"
    elif type_of_room == 3:
        room_price_per_day = 15000
        hotel_name= "Radisson Hotel - Shimla"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 8:
    location_name = "Kashmir"
  

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  2000")
    print("2. Super Deluxe room  3000")
    print("3. Deluxe Room  10000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 2000
        hotel_name= "Hotel Kashmir Inn"
    elif type_of_room == 2:
        room_price_per_day = 3000
        hotel_name= "Kashmir House Pahalgam"
    elif type_of_room == 3:
        room_price_per_day = 10000
        hotel_name= "Kashmir Mahal Resorts"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 9:
    location_name = "Sri Lanka"
    
    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  2500")
    print("2. Super Deluxe room  6000")
    print("3. Deluxe Room  2000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 2500
        hotel_name= "Grand Oriental Hotel"
    elif type_of_room == 2:
        room_price_per_day = 6000
        hotel_name= "Radisson Hotel Colombo"
    elif type_of_room == 3:
        room_price_per_day = 13000
        hotel_name= "Hotel Riu Sri Lanka"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 10:
    location_name = "Singapore"
    

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  9000")
    print("2. Super Deluxe room  11000")
    print("3. Deluxe Room  20000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 9000
        hotel_name= "Hotel Boss"
    elif type_of_room == 2:
        room_price_per_day = 11000
        hotel_name= "Park Regis Singapore"
    elif type_of_room == 3:
        room_price_per_day = 20000
        hotel_name= "Pan Pacific Serviced Suites Beach Road, Singapore"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 11:
    location_name = "Kerala"
    

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  1500")
    print("2. Super Deluxe room  7000")
    print("3. Deluxe Room  14000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 1500
        hotel_name= "Camelot Hotel"
    elif type_of_room == 2:
        room_price_per_day = 7000
        hotel_name= "The Leela Ashtamudi A Raviz Hotel"
    elif type_of_room == 3:
        room_price_per_day = 14000
        hotel_name= "The Leela Kovalam, a Raviz Hote"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
elif location == 12:
    location_name = "Bangalore"
    

    check_in_date = datetime.strptime(input("Enter the check-in date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    check_out_date = datetime.strptime(input("Enter the check-out date (DD-MM-YYYY): "), "%d-%m-%Y").date()
    print()
    Room_requirement = int(input("Enter the number of rooms required: "))
    print()
    adults = int(input("Enter the number of adults: "))
    print()
    children = int(input("Enter the number of children (0-17 years): "))
    print()

    print("1. Normal Room  1500")
    print("2. Super Deluxe room  6000")
    print("3. Deluxe Room  10000")

    type_of_room = int(input("Enter type of room requirement?: "))
    print()
    
    if type_of_room == 1:
        room_price_per_day = 1500
        hotel_name= "Hotel City Meridian"
    elif type_of_room == 2:
        room_price_per_day = 6000
        hotel_name= "Radisson Blu Hotel, Atria Bengaluru"
    elif type_of_room == 3:
        room_price_per_day = 10000
        hotel_name= "Sheraton Grand Bangalore Hotel at Brigade Gateway"   
    else:
        print("Invalid room choice. Please enter a number between 1 and 3.")
        exit()
    
    print("Location:", location_name)
    print("hotel_name:", hotel_name) 
    print("Check-in Date:", check_in_date)
    print("Check-out Date:", check_out_date)
    print("Room Requirement:", Room_requirement)
    print("Number of Adults:", adults)
    print("Number of Children:", children)
    print("Type of room requirement:", type_of_room)
    print("Room price per day:", room_price_per_day)
    print("Hotel price per day:", hotel_price_per_day)
    

    num_days = (check_out_date - check_in_date).days

    total_room_price = num_days * room_price_per_day

    print("Total Number of Days:", num_days)
    print()
    print("Total Price for rooms:", total_room_price * Room_requirement)
    print()
    
else:
    print("Invalid choice. Please select a city from 1 to 12.")
    exit()
# Out:
# 1. Pune
# 2. Mumbai
# 3. Delhi
# 4. Kolkata
# 5. Hyderabad
# 6. Chennai
# 7. Shimla
# 8. Kashmir
# 9. Sri Lanka
# 10. Singapore
# 11. Kerala
# 12. Bangalore
#
# Enter your location: 1
#
# Enter the check-in date (DD-MM-YYYY): 15-5-2024
#
# Enter the check-out date (DD-MM-YYYY): 20-5-2024
#
# Enter the number of rooms required: 2
#
# Enter the number of adults: 4
#
# Enter the number of children (0-17 years): 1
#
# 1. Normal Room  500
# 2. Super Deluxe room  1000
# 3. Deluxe Room  2000
# Enter type of room requirement?: 2
#
# Location: Pune
# hotel_name: Hamlet Studio Apartments with Balcony
# Check-in Date: 2024-05-15
# Check-out Date: 2024-05-20
# Room Requirement: 2
# Number of Adults: 4
# Number of Children: 1
# Type of room requirement: 2
# Room price per day: 1000
# Total Number of Days: 5
#
# Total Price for rooms: 10000
